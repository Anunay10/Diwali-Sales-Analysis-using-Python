# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Diwali_Sales.csv",encoding='unicode_escape')
df.shape
# Out:
# (11251, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.isnull().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
df.drop(["Status","unnamed1"],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
df.isna().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
df.head(7)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# 1    Andhra Pradesh  Southern             Govt             Auto       3
# 2     Uttar Pradesh   Central       Automobile             Auto       3
# 3         Karnataka  Southern     Construction             Auto       2
# ...

# %%
df["Amount"]=df["Amount"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age Group         11239 non-null  object
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  object
#  8   Zone              11239 non-null  object
#  9   Occupation        11239 non-null  object
#  10  Product_Category  11239 non-null  object
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  int32
# dtypes: int32(1), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
#Exploratory Data Analysis

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  Amount
# 0     Maharashtra   Western       Healthcare             Auto       1   23952
# 1  Andhra Pradesh  Southern             Govt             Auto       3   23934
# 2   Uttar Pradesh   Central       Automobile             Auto       3   23924
# 3       Karnataka  Southern     Construction             Auto       2   23912
# 4         Gujarat   Western  Food Processing             Auto       2   23877

# %%
sns.countplot(x="Gender",data=df)
plt.title("Gender counts")
# Out:
# Text(0.5, 1.0, 'Gender counts')

# %%
Sales_per_Gender=df.groupby("Gender")[["Amount"]].sum().sort_values("Amount",ascending=False).reset_index()
Sales_per_Gender
# Out:
#   Gender    Amount
# 0      F  74335853
# 1      M  31913276

# %%
sns.barplot(x="Gender",y="Amount",data=Sales_per_Gender)
plt.title("Who is spending more M or F ?")
# Out:
# Text(0.5, 1.0, 'Who is spending more M or F ?')

# %%
#From the above graphs, we can see that females tend to shop more frequent and also spends more than males

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sns.countplot(x="Age Group",data=df,hue="Gender")
plt.title("Males and Females counts in each Groups")
# Out:
# Text(0.5, 1.0, 'Males and Females counts in each Groups')

# %%
# This graphs shows that females in the age groups 26-35 are shopping more

# %%
AgeGroup_Analysis=df.groupby("Age Group")[["Amount"]].sum().sort_values("Amount",ascending=False).reset_index()
AgeGroup_Analysis
# Out:
#   Age Group    Amount
# 0     26-35  42613442
# 1     36-45  22144994
# 2     18-25  17240732
# 3     46-50   9207844
# 4     51-55   8261477
# 5       55+   4080987
# 6      0-17   2699653

# %%
sns.barplot(x="Age Group",y="Amount",data=AgeGroup_Analysis)
plt.title("Age Groups buying Potentials")
# Out:
# Text(0.5, 1.0, 'Age Groups buying Potentials')

# %%
# from the above graphs we can see that Females in age groups 26-35 are shopping more than others

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  Amount
# 0     Maharashtra   Western       Healthcare             Auto       1   23952
# 1  Andhra Pradesh  Southern             Govt             Auto       3   23934
# 2   Uttar Pradesh   Central       Automobile             Auto       3   23924
# 3       Karnataka  Southern     Construction             Auto       2   23912
# 4         Gujarat   Western  Food Processing             Auto       2   23877

# %%
Orders_by_States=df.groupby("State")[["Orders"]].sum().sort_values("Orders",ascending=False).reset_index().head(10)
Orders_by_States
# Out:
#               State  Orders
# 0     Uttar Pradesh    4807
# 1       Maharashtra    3810
# 2         Karnataka    3240
# 3             Delhi    2740
# 4    Madhya Pradesh    2252
# 5    Andhra Pradesh    2051
# 6  Himachal Pradesh    1568
# 7            Kerala    1137
# 8           Haryana    1109
# 9           Gujarat    1066

# %%
sns.barplot(x="State",y="Orders",data=Orders_by_States)
sns.set(rc={"figure.figsize": (20, 10)})
plt.title("Orders per States")
# Out:
# Text(0.5, 1.0, 'Orders per States')

# %%
# From the above graph, we can conclude that the people in UP have no. of orders more

# %%
Amount_per_State=df.groupby("State")[["Amount"]].sum().sort_values("Amount",ascending=False).reset_index().head(10)
Amount_per_State
# Out:
#               State    Amount
# 0     Uttar Pradesh  19374968
# 1       Maharashtra  14427543
# 2         Karnataka  13523540
# 3             Delhi  11603818
# 4    Madhya Pradesh   8101142
# 5    Andhra Pradesh   8037146
# 6  Himachal Pradesh   4963368
# 7           Haryana   4220175
# 8             Bihar   4022757
# 9           Gujarat   3946082

# %%
sns.barplot(x="State",y="Amount",data=Amount_per_State)
plt.title("Total Shopping Amonnt that states are spending during Daiwali")
# Out:
# Text(0.5, 1.0, 'Total Shopping Amonnt that states are spending during Daiwali')

# %%
# From the above graphs we can observe that people living in UP are odering more as well as spending more
#Also even though Ker is ordering more but Har is spending more than Ker

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sns.countplot(x="Marital_Status",data=df,hue="Gender")
sns.set(rc={"figure.figsize": (10, 4)})
plt.title("Married Count")
# Out:
# Text(0.5, 1.0, 'Married Count')

# %%
Married_spent=df.groupby("Marital_Status")[["Amount"]].sum().sort_values("Amount",ascending=False).reset_index()
Married_spent
# Out:
#    Marital_Status    Amount
# 0               0  62125384
# 1               1  44123745

# %%
sns.barplot(x="Marital_Status",y="Amount",data=Married_spent)
plt.title("Married Couple vs Non Married Couple Spending")
# Out:
# Text(0.5, 1.0, 'Married Couple vs Non Married Couple Spending')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sns.countplot(x="Occupation",data=df,hue="Gender")
sns.set(rc={"figure.figsize": (25, 4)})
plt.title("Gender distribution amongst Occupation")
# Out:
# Text(0.5, 1.0, 'Gender distribution amongst Occupation')

# %%
Occupation_per_Spending=df.groupby("Occupation")[["Amount"]].sum().sort_values("Amount",ascending=False).reset_index()
sns.barplot(x="Occupation",y="Amount",data=Occupation_per_Spending)
plt.title("Different Occupation Spending Power")
# Out:
# Text(0.5, 1.0, 'Different Occupation Spending Power')

# %%
# from the above graphs, we can conclude that females from IT sector are spending more

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sns.countplot(x="Product_Category",data=df)
plt.title("Product CAtegory Count")
# Out:
# Text(0.5, 1.0, 'Product CAtegory Count')

# %%
## no of orders in more in clothing

# %%
Product_Amount=df.groupby("Product_Category")[["Amount"]].sum().sort_values("Amount",ascending=False).reset_index().head(10)
sns.barplot(x="Product_Category",y="Amount",data=Product_Amount)
plt.title("Most spending done in which  category")
# Out:
# Text(0.5, 1.0, 'Most spending done in which  category')

# %%
## Even though more people are ordering clothes but amount spend in Food is more than clothing

# %%
#Conclusion-
# Married females from UP and in IT Sector are shopping more in Diwali. They are spending more in Food, Clothing and Electronics respectively
